# %%
import pandas as pd
import os

# %%
current_directory = os.getcwd()
current_directory
# Out:
# 'C:\\Users\\jackf\\OneDrive\\Desktop\\Bike_Sharing'

# %%
value_target_directory = r'C:\\Users\\jackf\\OneDrive\\Desktop\\Bike_Sharing\Data' ## replace value or same.

# %%
import pandas as pd
import os

# Directory where the combined_data.csv file is located
directory = value_target_directory

# File name
file_name = "combined_data.csv"

# Create the full path to the CSV file
csv_file_path = os.path.join(directory, file_name)

# Read the CSV file into a Pandas DataFrame
df = pd.read_csv(csv_file_path)

# Now, you can work with the DataFrame 'df' as needed
df.head(5)
# Out:
# C:\Users\jackf\AppData\Local\Temp\ipykernel_22784\2801364683.py:14: DtypeWarning: Columns (10,17,19,20,21,22,23,24) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(csv_file_path)
#      trip_id  duration      start_time        end_time  start_station_id  \
# 0  1912818.0       3.0   7/7/2016 4:17   7/7/2016 4:20            3014.0
# 1  1919661.0      33.0   7/7/2016 6:00   7/7/2016 6:33            3014.0
# 2  1933383.0       5.0  7/7/2016 10:32  7/7/2016 10:37            3016.0
# 3  1944197.0     181.0  7/7/2016 10:37  7/7/2016 13:38            3016.0
# 4  1940317.0       7.0  7/7/2016 12:51  7/7/2016 12:58            3032.0
#
#    start_lat  start_lon  end_station_id    end_lat    end_lon  ...  \
# 0  34.056610 -118.23721          3014.0  34.056610 -118.23721  ...
# 1  34.056610 -118.23721          3014.0  34.056610 -118.23721  ...
# 2  34.052898 -118.24156          3016.0  34.052898 -118.24156  ...
# ...

# %%
df.describe()
# Out:
#             trip_id      duration  start_station_id     start_lat  \
# count  1.782931e+06  1.782931e+06      89225.000000  1.772797e+06
# mean   1.407687e+08  3.619042e+01       3042.989644  3.404176e+01
# std    7.860774e+07  1.181368e+02         41.420004  3.196814e-01
# min    1.912818e+06  1.000000e+00       3000.000000  0.000000e+00
# 25%    9.002476e+07  7.000000e+00       3024.000000  3.402788e+01
# 50%    1.323710e+08  1.400000e+01       3038.000000  3.404613e+01
# 75%    1.909776e+08  2.700000e+01       3063.000000  3.405194e+01
# max    3.107300e+08  1.440000e+03       4108.000000  5.570553e+01
#
#           start_lon  end_station_id       end_lat       end_lon  \
# count  1.772797e+06    89225.000000  1.741473e+06  1.741473e+06
# mean  -1.182740e+02     3042.444068  3.404129e+01 -1.182715e+02
# std    2.095564e+00       47.273035  3.333270e-01  2.213469e+00
# min   -1.184954e+02     3000.000000  0.000000e+00 -1.184954e+02
# ...

# %%
drop_columns = ['3000', 'Virtual Station', '7/7/2016', 'N/A', 'Active',
                'start station name', 'end station name', 'Unnamed: 0',
                'start_station_id', 'end_station_id']

# Drop the specified columns from the DataFrame
bike_sharing_data = df.drop(columns=drop_columns)
bike_sharing_data
# Out:
#              trip_id  duration       start_time         end_time  start_lat  \
# 0          1912818.0       3.0    7/7/2016 4:17    7/7/2016 4:20  34.056610
# 1          1919661.0      33.0    7/7/2016 6:00    7/7/2016 6:33  34.056610
# 2          1933383.0       5.0   7/7/2016 10:32   7/7/2016 10:37  34.052898
# 3          1944197.0     181.0   7/7/2016 10:37   7/7/2016 13:38  34.052898
# 4          1940317.0       7.0   7/7/2016 12:51   7/7/2016 12:58  34.049889
# ...              ...       ...              ...              ...        ...
# 1783615  307634258.0      14.0  9/30/2023 23:55   10/1/2023 0:09  34.056808
# 1783616  307620079.0       2.0  9/30/2023 23:56  9/30/2023 23:58  34.059689
# 1783617  307635023.0      47.0  9/30/2023 23:58   10/1/2023 0:45  34.098228
# 1783618  307635024.0      47.0  9/30/2023 23:58   10/1/2023 0:45  34.098228
# 1783619  307634259.0      10.0  9/30/2023 23:59   10/1/2023 0:09  34.057652
#
# ...

# %%
len(bike_sharing_data)
# Out:
# 1783620

# %%
import pandas as pd

# Assuming your DataFrame is named bike_sharing_data
# Convert "start_time" to datetime format with error handling
bike_sharing_data['start_time'] = pd.to_datetime(bike_sharing_data['start_time'], errors='coerce')

# Create a new column with day, month, and year
bike_sharing_data['date_only'] = bike_sharing_data['start_time'].dt.strftime('%m/%d/%Y')

# Display the updated DataFrame
(bike_sharing_data.head())
# Out:
#      trip_id  duration          start_time        end_time  start_lat  \
# 0  1912818.0       3.0 2016-07-07 04:17:00   7/7/2016 4:20  34.056610
# 1  1919661.0      33.0 2016-07-07 06:00:00   7/7/2016 6:33  34.056610
# 2  1933383.0       5.0 2016-07-07 10:32:00  7/7/2016 10:37  34.052898
# 3  1944197.0     181.0 2016-07-07 10:37:00  7/7/2016 13:38  34.052898
# 4  1940317.0       7.0 2016-07-07 12:51:00  7/7/2016 12:58  34.049889
#
#    start_lon    end_lat    end_lon bike_id  plan_duration trip_route_category  \
# 0 -118.23721  34.056610 -118.23721    6281           30.0          Round Trip
# 1 -118.23721  34.056610 -118.23721    6281           30.0          Round Trip
# 2 -118.24156  34.052898 -118.24156    5861          365.0          Round Trip
# 3 -118.24156  34.052898 -118.24156    5861          365.0          Round Trip
# 4 -118.25588  34.049889 -118.25588    6674            0.0          Round Trip
#
#   passholder_type  start_station  end_station bike_type   date_only
# ...

# %%
bike_sharing_data["date_only"]
# Out:
# 0          07/07/2016
# 1          07/07/2016
# 2          07/07/2016
# 3          07/07/2016
# 4          07/07/2016
#               ...
# 1783615    09/30/2023
# 1783616    09/30/2023
# 1783617    09/30/2023
# 1783618    09/30/2023
# 1783619    09/30/2023
# Name: date_only, Length: 1783620, dtype: object

# %%
import pandas as pd
LA = pd.read_csv('LAWEATHER.csv') 
LA.head()
# Out:
#           dt                         dt_iso  timezone    city_name        lat  \
# 0  283996800  1979-01-01 00:00:00 +0000 UTC    -28800  Los Angeles  34.054908
# 1  284000400  1979-01-01 01:00:00 +0000 UTC    -28800  Los Angeles  34.054908
# 2  284004000  1979-01-01 02:00:00 +0000 UTC    -28800  Los Angeles  34.054908
# 3  284007600  1979-01-01 03:00:00 +0000 UTC    -28800  Los Angeles  34.054908
# 4  284011200  1979-01-01 04:00:00 +0000 UTC    -28800  Los Angeles  34.054908
#
#           lon    temp  visibility  dew_point  feels_like  ...  wind_gust  \
# 0 -118.242643  288.74         NaN     280.00      287.82  ...        NaN
# 1 -118.242643  289.80         NaN     277.83      288.70  ...        NaN
# 2 -118.242643  288.28         NaN     277.36      287.10  ...        NaN
# 3 -118.242643  281.05         NaN     275.92      281.05  ...        NaN
# 4 -118.242643  280.67         NaN     275.56      280.67  ...        NaN
#
# ...

# %%
LA["dt_iso"]
# Out:
# 0         1979-01-01 00:00:00 +0000 UTC
# 1         1979-01-01 01:00:00 +0000 UTC
# 2         1979-01-01 02:00:00 +0000 UTC
# 3         1979-01-01 03:00:00 +0000 UTC
# 4         1979-01-01 04:00:00 +0000 UTC
#                       ...
# 396126    2023-12-01 19:00:00 +0000 UTC
# 396127    2023-12-01 20:00:00 +0000 UTC
# 396128    2023-12-01 21:00:00 +0000 UTC
# 396129    2023-12-01 22:00:00 +0000 UTC
# 396130    2023-12-01 23:00:00 +0000 UTC
# Name: dt_iso, Length: 396131, dtype: object

# %%
import pandas as pd

# Assuming your DataFrame is named LA
# Convert "dt_iso" to datetime format with explicit format
LA['dt_iso'] = pd.to_datetime(LA['dt_iso'], format='%Y-%m-%d %H:%M:%S +0000 UTC')

# Extract and format date component
LA['date_only'] = LA['dt_iso'].dt.strftime('%m/%d/%Y')

# Display the updated DataFrame
(LA.head())
# Out:
#           dt              dt_iso  timezone    city_name        lat  \
# 0  283996800 1979-01-01 00:00:00    -28800  Los Angeles  34.054908
# 1  284000400 1979-01-01 01:00:00    -28800  Los Angeles  34.054908
# 2  284004000 1979-01-01 02:00:00    -28800  Los Angeles  34.054908
# 3  284007600 1979-01-01 03:00:00    -28800  Los Angeles  34.054908
# 4  284011200 1979-01-01 04:00:00    -28800  Los Angeles  34.054908
#
#           lon    temp  visibility  dew_point  feels_like  ...  rain_1h  \
# 0 -118.242643  288.74         NaN     280.00      287.82  ...      NaN
# 1 -118.242643  289.80         NaN     277.83      288.70  ...      NaN
# 2 -118.242643  288.28         NaN     277.36      287.10  ...      NaN
# 3 -118.242643  281.05         NaN     275.92      281.05  ...      NaN
# 4 -118.242643  280.67         NaN     275.56      280.67  ...      NaN
#
#    rain_3h  snow_1h  snow_3h  clouds_all  weather_id  weather_main  \
# ...

# %%
merged_data = pd.merge(bike_sharing_data, LA, on='date_only', how='inner')
merged_data.head(5)
# Out:
#      trip_id  duration          start_time       end_time  start_lat  \
# 0  1912818.0       3.0 2016-07-07 04:17:00  7/7/2016 4:20   34.05661
# 1  1912818.0       3.0 2016-07-07 04:17:00  7/7/2016 4:20   34.05661
# 2  1912818.0       3.0 2016-07-07 04:17:00  7/7/2016 4:20   34.05661
# 3  1912818.0       3.0 2016-07-07 04:17:00  7/7/2016 4:20   34.05661
# 4  1912818.0       3.0 2016-07-07 04:17:00  7/7/2016 4:20   34.05661
#
#    start_lon   end_lat    end_lon bike_id  plan_duration  ... wind_gust  \
# 0 -118.23721  34.05661 -118.23721    6281           30.0  ...       NaN
# 1 -118.23721  34.05661 -118.23721    6281           30.0  ...       NaN
# 2 -118.23721  34.05661 -118.23721    6281           30.0  ...       NaN
# 3 -118.23721  34.05661 -118.23721    6281           30.0  ...       NaN
# 4 -118.23721  34.05661 -118.23721    6281           30.0  ...       NaN
#
#   rain_1h  rain_3h  snow_1h snow_3h clouds_all  weather_id weather_main  \
# ...

# %%
len(bike_sharing_data)
# Out:
# 1783620

# %%
len(LA)
# Out:
# 396131

# %%
merged_data = merged_data.copy() ## Because large dataset, to prevent overflow. 
merged_data.head(5)
# Out:
#      trip_id  duration          start_time       end_time  start_lat  \
# 0  1912818.0       3.0 2016-07-07 04:17:00  7/7/2016 4:20   34.05661
# 1  1912818.0       3.0 2016-07-07 04:17:00  7/7/2016 4:20   34.05661
# 2  1912818.0       3.0 2016-07-07 04:17:00  7/7/2016 4:20   34.05661
# 3  1912818.0       3.0 2016-07-07 04:17:00  7/7/2016 4:20   34.05661
# 4  1912818.0       3.0 2016-07-07 04:17:00  7/7/2016 4:20   34.05661
#
#    start_lon   end_lat    end_lon bike_id  plan_duration  ... wind_gust  \
# 0 -118.23721  34.05661 -118.23721    6281           30.0  ...       NaN
# 1 -118.23721  34.05661 -118.23721    6281           30.0  ...       NaN
# 2 -118.23721  34.05661 -118.23721    6281           30.0  ...       NaN
# 3 -118.23721  34.05661 -118.23721    6281           30.0  ...       NaN
# 4 -118.23721  34.05661 -118.23721    6281           30.0  ...       NaN
#
#   rain_1h  rain_3h  snow_1h snow_3h clouds_all  weather_id weather_main  \
# ...

# %%
import pandas as pd

# Assuming your DataFrame is named merged_data
# Convert "start_time" to datetime format if not already done
merged_data['start_time'] = pd.to_datetime(merged_data['start_time'])

# Extract day, month, and year components
merged_data['day'] = merged_data['start_time'].dt.day
merged_data['month'] = merged_data['start_time'].dt.month
merged_data['year'] = merged_data['start_time'].dt.year

# Display the updated DataFrame
merged_data.head()
# Out:
#      trip_id  duration          start_time       end_time  start_lat  \
# 0  1912818.0       3.0 2016-07-07 04:17:00  7/7/2016 4:20   34.05661
# 1  1912818.0       3.0 2016-07-07 04:17:00  7/7/2016 4:20   34.05661
# 2  1912818.0       3.0 2016-07-07 04:17:00  7/7/2016 4:20   34.05661
# 3  1912818.0       3.0 2016-07-07 04:17:00  7/7/2016 4:20   34.05661
# 4  1912818.0       3.0 2016-07-07 04:17:00  7/7/2016 4:20   34.05661
#
#    start_lon   end_lat    end_lon bike_id  plan_duration  ... snow_1h snow_3h  \
# 0 -118.23721  34.05661 -118.23721    6281           30.0  ...     NaN     NaN
# 1 -118.23721  34.05661 -118.23721    6281           30.0  ...     NaN     NaN
# 2 -118.23721  34.05661 -118.23721    6281           30.0  ...     NaN     NaN
# 3 -118.23721  34.05661 -118.23721    6281           30.0  ...     NaN     NaN
# 4 -118.23721  34.05661 -118.23721    6281           30.0  ...     NaN     NaN
#
#    clouds_all  weather_id weather_main weather_description  weather_icon day  \
# ...

# %%
len(merged_data)
# Out:
# 26734116

# %%
## To do
